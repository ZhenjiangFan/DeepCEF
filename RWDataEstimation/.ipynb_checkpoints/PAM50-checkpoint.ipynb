# %%
import numpy as np
import pandas as pd
import networkx as nx

import Utils as Utils

# %%
data_path = "SimulationData/PAM50/";
file_name = "BRCADataPM50.txt";
BRCADataPM50 = pd.read_csv(data_path+file_name,sep='\t');
display(BRCADataPM50);
#print(mixed_sim_dataset.columns);
# Out:
#       CLEC3A     CPB1  SCGB2A2  SCGB1D2     TFF1    GSTM1      PIP  S100A7  \
# 0     1.7015   6.6126   8.3479   7.7986   2.5742   0.0000   5.5251  0.0000
# 1     4.0415   6.2547  10.8725   9.9367  13.1286  12.6025   7.3682  0.0000
# 2     0.8928   6.5801  14.1237  10.6065  13.1892  10.5203  10.3385  0.0000
# 3     0.0000   3.6913  17.1161  15.5172   9.8676   8.1795   7.9117  0.4449
# 4    11.8279   6.9578  10.0564   5.5244   4.2665   0.9130  10.6559  0.0000
# ..       ...      ...      ...      ...      ...      ...      ...     ...
# 596   0.0000   4.0715   3.1285   5.4674   0.0000   7.6400   2.9592  2.5462
# 597   3.1862  11.6245   8.0968   4.8590   9.6830   0.0000   4.1047  0.7443
# 598  15.5830  10.1516  15.6385  14.1262  12.4475   2.5281  12.7570  2.3597
# 599   4.0102  19.2823  12.6806  10.2340   7.4761   7.0284   5.7131  1.8151
# 600   0.0000   5.0938  15.9997  13.8440  11.5395   1.0738  13.3009  1.4101
#
#        MUCL1  CYP2B7P1  ...  COL9A3    IRX1     AFP  LOC339535  PDZK1IP1  \
# 0     4.8089    1.8887  ...  9.3336  8.3217  0.0000     7.2256    7.2343
# 1    10.6232    6.3334  ...  5.9591  8.3767  1.2118     0.4104    8.7694
# 2     6.6495    8.7548  ...  5.7351  7.9251  1.1923     2.2796    7.8969
# 3     9.6917    5.6983  ...  6.5462  7.8543  3.5649     1.2896    6.4660
# 4    14.8774    8.0641  ...  5.9106  5.2731  5.3992     4.8849    9.4650
# ..       ...       ...  ...     ...     ...     ...        ...       ...
# 596   0.7184    2.3772  ...  6.1955  1.3860  0.4035     6.1438   11.5044
# 597   9.2764   10.6440  ...  7.9311  5.7368  1.2328     2.6784    4.5618
# 598  16.5419   12.1057  ...  4.5782  3.8431  0.9662     2.2674   11.6040
# 599   9.9208    9.0875  ...  5.6524  6.4608  1.2865     4.9311    6.4067
# 600  13.1395    9.8408  ...  2.9316  8.2779  1.0738     4.5639    9.8853
#
#      LOC84740  LOC440905     CDH1    ERBB2  PAM50Call_RNAseq
# 0      4.2191     6.0709  14.5226  12.7126                 1
# 1      2.5703     6.1650  13.3517  13.1849                 2
# 2      3.2608    10.1397  13.9822  12.9618                 2
# 3      2.4181     5.8774  13.2457  14.1351                 2
# 4      3.7149     2.4368  13.3157  12.1305                 3
# ..        ...        ...      ...      ...               ...
# 596    9.8210     5.9083  12.1229  11.6357                 4
# 597    1.8944     6.4104  14.7650  14.0283                 2
# 598    3.4868     4.8567  14.0134  12.7355                 2
# 599    3.3265     6.0473  15.2450  12.4689                 2
# 600    3.5253     4.9465  12.4367  12.8286                 1
#
# [601 rows x 503 columns]

# %%
# BRCADataPM50.to_csv(data_path+'BRCADataPM50.csv',index=None)

# %%
#Dict that contains info if a variable is discrete or not (discrete if True, countinous elsewise)
data_type_dict, discrete_list = Utils.check_variable_type(BRCADataPM50);

#Map the feature names with indeces
#Convert the columns to their numerical representations
name_index_mapping = {};
index_name_mapping = {};
index_data_type_dict = {};
colList = BRCADataPM50.columns.tolist();
for index,name in enumerate(colList):
    name_index_mapping[name] = index;
    index_name_mapping[index] = name;
    index_data_type_dict[index] = data_type_dict[name];
# print(name_index_mapping);
# print(index_name_mapping);
# print(index_data_type_dict);
    
#Target feature list
target_var_list = ['PAM50Call_RNAseq'];

var_list = list(BRCADataPM50.columns);

temp_relations_list = [];

#When there is a target feature list defined, the iteration strategy is different when there is not target features defined.
if len(target_var_list)>0:
    for target in target_var_list:
        for var in var_list:
            if var!=target:
                idx1 = name_index_mapping[target];
                idx2 = name_index_mapping[var];
                temp_relations_list.append((idx1,idx2));
                print(str(target)+"-"+str(var));
# Out:
# PAM50Call_RNAseq-CLEC3A
# PAM50Call_RNAseq-CPB1
# PAM50Call_RNAseq-SCGB2A2
# PAM50Call_RNAseq-SCGB1D2
# PAM50Call_RNAseq-TFF1
# PAM50Call_RNAseq-GSTM1
# PAM50Call_RNAseq-PIP
# PAM50Call_RNAseq-S100A7
# PAM50Call_RNAseq-MUCL1
# PAM50Call_RNAseq-CYP2B7P1
# PAM50Call_RNAseq-ANKRD30A
# PAM50Call_RNAseq-PRAME
# PAM50Call_RNAseq-CYP4Z1
# PAM50Call_RNAseq-KCNJ3
# PAM50Call_RNAseq-AGR3
# PAM50Call_RNAseq-HMGCS2
# PAM50Call_RNAseq-TFAP2B
# PAM50Call_RNAseq-SERPINA6
# PAM50Call_RNAseq-MUC6
# PAM50Call_RNAseq-DHRS2
# PAM50Call_RNAseq-SLC30A8
# PAM50Call_RNAseq-UGT2B11
# PAM50Call_RNAseq-COL2A1
# PAM50Call_RNAseq-VSTM2A
# PAM50Call_RNAseq-C4orf7
# PAM50Call_RNAseq-TAT
# PAM50Call_RNAseq-ADIPOQ
# PAM50Call_RNAseq-ADH1B
# PAM50Call_RNAseq-CALML5
# PAM50Call_RNAseq-GP2
# PAM50Call_RNAseq-GABRP
# PAM50Call_RNAseq-MYBPC1
# PAM50Call_RNAseq-KRT14
# PAM50Call_RNAseq-CEACAM5
# PAM50Call_RNAseq-MUC5B
# PAM50Call_RNAseq-TFF3
# PAM50Call_RNAseq-C1orf64
# PAM50Call_RNAseq-SOX10
# PAM50Call_RNAseq-GRIA2
# PAM50Call_RNAseq-KRT5
# PAM50Call_RNAseq-CRABP1
# PAM50Call_RNAseq-GSTT1
# PAM50Call_RNAseq-SYT13
# PAM50Call_RNAseq-CST9
# PAM50Call_RNAseq-STAC2
# PAM50Call_RNAseq-LTF
# PAM50Call_RNAseq-KRT6B
# PAM50Call_RNAseq-BMPR1B
# PAM50Call_RNAseq-HOXB13
# PAM50Call_RNAseq-KLK11
# PAM50Call_RNAseq-CYP2A6
# PAM50Call_RNAseq-FABP7
# PAM50Call_RNAseq-NPY1R
# PAM50Call_RNAseq-CEACAM6
# PAM50Call_RNAseq-GFRA1
# PAM50Call_RNAseq-ABCC11
# PAM50Call_RNAseq-CRISP3
# PAM50Call_RNAseq-C20orf114
# PAM50Call_RNAseq-CLCA2
# PAM50Call_RNAseq-KIF1A
# PAM50Call_RNAseq-PVALB
# PAM50Call_RNAseq-TCN1
# PAM50Call_RNAseq-LRP2
# PAM50Call_RNAseq-CP
# PAM50Call_RNAseq-CGA
# PAM50Call_RNAseq-AGR2
# PAM50Call_RNAseq-OBP2B
# PAM50Call_RNAseq-PGR
# PAM50Call_RNAseq-SLC34A2
# PAM50Call_RNAseq-KCNC2
# PAM50Call_RNAseq-OLFM4
# PAM50Call_RNAseq-KRT6A
# PAM50Call_RNAseq-MUC16
# PAM50Call_RNAseq-KLK5
# PAM50Call_RNAseq-CYP4F8
# PAM50Call_RNAseq-PROM1
# PAM50Call_RNAseq-MSLN
# PAM50Call_RNAseq-KRT16
# PAM50Call_RNAseq-BPIL1
# PAM50Call_RNAseq-DSG3
# PAM50Call_RNAseq-FAM5C
# PAM50Call_RNAseq-A2ML1
# PAM50Call_RNAseq-SLC5A8
# PAM50Call_RNAseq-SERPINA11
# PAM50Call_RNAseq-CBLN2
# PAM50Call_RNAseq-PIGR
# PAM50Call_RNAseq-NLRP2
# PAM50Call_RNAseq-AQP5
# PAM50Call_RNAseq-PTPRT
# PAM50Call_RNAseq-ELF5
# PAM50Call_RNAseq-KRT81
# PAM50Call_RNAseq-KRT17
# PAM50Call_RNAseq-CA9
# PAM50Call_RNAseq-BEX1
# PAM50Call_RNAseq-VGLL1
# PAM50Call_RNAseq-CST1
# PAM50Call_RNAseq-TUSC5
# PAM50Call_RNAseq-SLC6A4
# PAM50Call_RNAseq-KLK6
# PAM50Call_RNAseq-LBP
# PAM50Call_RNAseq-CYP4Z2P
# PAM50Call_RNAseq-KLK10
# PAM50Call_RNAseq-NXPH1
# PAM50Call_RNAseq-PPP1R1B
# PAM50Call_RNAseq-SLITRK6
# PAM50Call_RNAseq-KLHDC7A
# PAM50Call_RNAseq-LRRC31
# PAM50Call_RNAseq-C10orf82
# PAM50Call_RNAseq-ESR1
# PAM50Call_RNAseq-PPP2R2C
# PAM50Call_RNAseq-EEF1A2
# PAM50Call_RNAseq-SYT9
# PAM50Call_RNAseq-ANKRD30B
# PAM50Call_RNAseq-DCD
# PAM50Call_RNAseq-SCGB2A1
# PAM50Call_RNAseq-ORM1
# PAM50Call_RNAseq-GRPR
# PAM50Call_RNAseq-CALML3
# PAM50Call_RNAseq-FABP4
# PAM50Call_RNAseq-TNNT1
# PAM50Call_RNAseq-CHAD
# PAM50Call_RNAseq-SORCS1
# PAM50Call_RNAseq-CST5
# PAM50Call_RNAseq-KLK7
# PAM50Call_RNAseq-MAGEA6
# PAM50Call_RNAseq-ASCL1
# PAM50Call_RNAseq-CDC20B
# PAM50Call_RNAseq-PDZK1
# PAM50Call_RNAseq-CLIC6
# PAM50Call_RNAseq-MUC2
# PAM50Call_RNAseq-CXCL17
# PAM50Call_RNAseq-SLC6A14
# PAM50Call_RNAseq-RPS28
# PAM50Call_RNAseq-PEG10
# PAM50Call_RNAseq-DIO1
# PAM50Call_RNAseq-CARTPT
# PAM50Call_RNAseq-FOXI1
# PAM50Call_RNAseq-NBPF4
# PAM50Call_RNAseq-SPAG6
# PAM50Call_RNAseq-CNTNAP2
# PAM50Call_RNAseq-C7
# PAM50Call_RNAseq-CASP14
# PAM50Call_RNAseq-SDR16C5
# PAM50Call_RNAseq-ABCC8
# PAM50Call_RNAseq-PYDC1
# PAM50Call_RNAseq-WNK4
# PAM50Call_RNAseq-MUC15
# PAM50Call_RNAseq-LCN2
# PAM50Call_RNAseq-CIDEC
# PAM50Call_RNAseq-SCUBE2
# PAM50Call_RNAseq-S100A8
# PAM50Call_RNAseq-PPAN-P2RY11
# PAM50Call_RNAseq-S100A7A
# PAM50Call_RNAseq-MIA
# PAM50Call_RNAseq-ABCA12
# PAM50Call_RNAseq-PGLYRP2
# PAM50Call_RNAseq-SCGB3A1
# PAM50Call_RNAseq-FOLR1
# PAM50Call_RNAseq-DSC3
# PAM50Call_RNAseq-CAPN8
# PAM50Call_RNAseq-C2orf54
# PAM50Call_RNAseq-CXCL13
# PAM50Call_RNAseq-MSMB
# PAM50Call_RNAseq-IGSF1
# PAM50Call_RNAseq-S100A9
# PAM50Call_RNAseq-LRP1B
# PAM50Call_RNAseq-TMPRSS4
# PAM50Call_RNAseq-MAGEA3
# PAM50Call_RNAseq-SERPINA5
# PAM50Call_RNAseq-GLYATL2
# PAM50Call_RNAseq-HS6ST3
# PAM50Call_RNAseq-LY6D
# PAM50Call_RNAseq-TRH
# PAM50Call_RNAseq-SERPINB5
# PAM50Call_RNAseq-SLC7A4
# PAM50Call_RNAseq-SLC5A1
# PAM50Call_RNAseq-MMP1
# PAM50Call_RNAseq-PON3
# PAM50Call_RNAseq-SLC44A4
# PAM50Call_RNAseq-PLA2G2A
# PAM50Call_RNAseq-SFRP1
# PAM50Call_RNAseq-NBPF6
# PAM50Call_RNAseq-ERBB4
# PAM50Call_RNAseq-COL17A1
# PAM50Call_RNAseq-ALB
# PAM50Call_RNAseq-ZIC1
# PAM50Call_RNAseq-S100P
# PAM50Call_RNAseq-ROBO2
# PAM50Call_RNAseq-RIMS4
# PAM50Call_RNAseq-ORM2
# PAM50Call_RNAseq-CYP4F22
# PAM50Call_RNAseq-NEK10
# PAM50Call_RNAseq-WIF1
# PAM50Call_RNAseq-ABCC13
# PAM50Call_RNAseq-ROPN1
# PAM50Call_RNAseq-NCRNA00052
# PAM50Call_RNAseq-GLRA3
# PAM50Call_RNAseq-PI16
# PAM50Call_RNAseq-TMC5
# PAM50Call_RNAseq-IL20
# PAM50Call_RNAseq-LPPR3
# PAM50Call_RNAseq-ELOVL2
# PAM50Call_RNAseq-CCL19
# PAM50Call_RNAseq-INSM1
# PAM50Call_RNAseq-TSPAN8
# PAM50Call_RNAseq-PI3
# PAM50Call_RNAseq-SLC9A2
# PAM50Call_RNAseq-LEP
# PAM50Call_RNAseq-SLC7A2
# PAM50Call_RNAseq-FREM2
# PAM50Call_RNAseq-MS4A15
# PAM50Call_RNAseq-HGD
# PAM50Call_RNAseq-WFDC2
# PAM50Call_RNAseq-LOC728606
# PAM50Call_RNAseq-ATP6V0A4
# PAM50Call_RNAseq-KNDC1
# PAM50Call_RNAseq-FAM3B
# PAM50Call_RNAseq-WDR72
# PAM50Call_RNAseq-FGB
# PAM50Call_RNAseq-CAPN6
# PAM50Call_RNAseq-NKAIN1
# PAM50Call_RNAseq-CHST8
# PAM50Call_RNAseq-ATP13A5
# PAM50Call_RNAseq-SYT1
# PAM50Call_RNAseq-NCCRP1
# PAM50Call_RNAseq-TRPA1
# PAM50Call_RNAseq-FOXJ1
# PAM50Call_RNAseq-PTPRZ1
# PAM50Call_RNAseq-FAM5B
# PAM50Call_RNAseq-HORMAD1
# PAM50Call_RNAseq-ANXA8
# PAM50Call_RNAseq-VTCN1
# PAM50Call_RNAseq-CYP4B1
# PAM50Call_RNAseq-SYTL5
# PAM50Call_RNAseq-CCL21
# PAM50Call_RNAseq-KLK8
# PAM50Call_RNAseq-CR2
# PAM50Call_RNAseq-PKP1
# PAM50Call_RNAseq-ACTL8
# PAM50Call_RNAseq-GRB14
# PAM50Call_RNAseq-SPDYC
# PAM50Call_RNAseq-KRT15
# PAM50Call_RNAseq-AGTR1
# PAM50Call_RNAseq-GLDC
# PAM50Call_RNAseq-PLIN1
# PAM50Call_RNAseq-CHGB
# PAM50Call_RNAseq-BCAS1
# PAM50Call_RNAseq-GPD1
# PAM50Call_RNAseq-BBOX1
# PAM50Call_RNAseq-TPRG1
# PAM50Call_RNAseq-TMPRSS6
# PAM50Call_RNAseq-C16orf89
# PAM50Call_RNAseq-ART3
# PAM50Call_RNAseq-GPR98
# PAM50Call_RNAseq-HOTAIR
# PAM50Call_RNAseq-TUBA3D
# PAM50Call_RNAseq-SYT8
# PAM50Call_RNAseq-CYP4X1
# PAM50Call_RNAseq-FSIP1
# PAM50Call_RNAseq-MS4A1
# PAM50Call_RNAseq-PROL1
# PAM50Call_RNAseq-NAT1
# PAM50Call_RNAseq-SLPI
# PAM50Call_RNAseq-LRG1
# PAM50Call_RNAseq-CYP2A7
# PAM50Call_RNAseq-GSTA1
# PAM50Call_RNAseq-FAM196A
# PAM50Call_RNAseq-CIDEA
# PAM50Call_RNAseq-NDP
# PAM50Call_RNAseq-TRIM29
# PAM50Call_RNAseq-DLK1
# PAM50Call_RNAseq-ROPN1B
# PAM50Call_RNAseq-FLJ45983
# PAM50Call_RNAseq-CHIT1
# PAM50Call_RNAseq-ZIC2
# PAM50Call_RNAseq-SOSTDC1
# PAM50Call_RNAseq-PAX7
# PAM50Call_RNAseq-HEPACAM2
# PAM50Call_RNAseq-ALOX15B
# PAM50Call_RNAseq-PPP4R4
# PAM50Call_RNAseq-IGDCC3
# PAM50Call_RNAseq-PCSK1N
# PAM50Call_RNAseq-CST4
# PAM50Call_RNAseq-MARCO
# PAM50Call_RNAseq-PNMT
# PAM50Call_RNAseq-ATRNL1
# PAM50Call_RNAseq-TF
# PAM50Call_RNAseq-PSCA
# PAM50Call_RNAseq-MMP12
# PAM50Call_RNAseq-RGS22
# PAM50Call_RNAseq-DSG1
# PAM50Call_RNAseq-ANXA8L2
# PAM50Call_RNAseq-C2CD4A
# PAM50Call_RNAseq-GPR26
# PAM50Call_RNAseq-SLC13A2
# PAM50Call_RNAseq-AKR7A3
# PAM50Call_RNAseq-LOC100271831
# PAM50Call_RNAseq-HOXC11
# PAM50Call_RNAseq-GABRB3
# PAM50Call_RNAseq-GJB1
# PAM50Call_RNAseq-ONECUT2
# PAM50Call_RNAseq-PRODH
# PAM50Call_RNAseq-RBM24
# PAM50Call_RNAseq-C1orf173
# PAM50Call_RNAseq-KRT6C
# PAM50Call_RNAseq-KRT23
# PAM50Call_RNAseq-C19orf33
# PAM50Call_RNAseq-GRIK3
# PAM50Call_RNAseq-C3orf57
# PAM50Call_RNAseq-FOXA1
# PAM50Call_RNAseq-TRPV6
# PAM50Call_RNAseq-SAA2
# PAM50Call_RNAseq-THRSP
# PAM50Call_RNAseq-KRT4
# PAM50Call_RNAseq-FUT3
# PAM50Call_RNAseq-UGT2B15
# PAM50Call_RNAseq-TMPRSS3
# PAM50Call_RNAseq-ARHGAP36
# PAM50Call_RNAseq-DARC
# PAM50Call_RNAseq-IGJ
# PAM50Call_RNAseq-SHISA9
# PAM50Call_RNAseq-VSIG2
# PAM50Call_RNAseq-PPP1R14C
# PAM50Call_RNAseq-SAA1
# PAM50Call_RNAseq-POF1B
# PAM50Call_RNAseq-TPSG1
# PAM50Call_RNAseq-VIPR2
# PAM50Call_RNAseq-PRSS21
# PAM50Call_RNAseq-KRT13
# PAM50Call_RNAseq-TFPI2
# PAM50Call_RNAseq-HBA1
# PAM50Call_RNAseq-TDRD1
# PAM50Call_RNAseq-PLIN4
# PAM50Call_RNAseq-SLC26A3
# PAM50Call_RNAseq-TTYH1
# PAM50Call_RNAseq-AREG
# PAM50Call_RNAseq-SLC28A3
# PAM50Call_RNAseq-PLCH1
# PAM50Call_RNAseq-MMP13
# PAM50Call_RNAseq-AR
# PAM50Call_RNAseq-DKK1
# PAM50Call_RNAseq-CCNO
# PAM50Call_RNAseq-DLX2
# PAM50Call_RNAseq-SYNPO2L
# PAM50Call_RNAseq-CXADRP3
# PAM50Call_RNAseq-AFF3
# PAM50Call_RNAseq-S100A2
# PAM50Call_RNAseq-ATP13A4
# PAM50Call_RNAseq-AKR1B10
# PAM50Call_RNAseq-SPAG17
# PAM50Call_RNAseq-SBSN
# PAM50Call_RNAseq-NTNG1
# PAM50Call_RNAseq-PI15
# PAM50Call_RNAseq-PCDHA11
# PAM50Call_RNAseq-HSD17B2
# PAM50Call_RNAseq-FAM83E
# PAM50Call_RNAseq-ZNF385B
# PAM50Call_RNAseq-ANKRD43
# PAM50Call_RNAseq-F7
# PAM50Call_RNAseq-NPY5R
# PAM50Call_RNAseq-DCX
# PAM50Call_RNAseq-MAPK4
# PAM50Call_RNAseq-MYT1
# PAM50Call_RNAseq-NELL2
# PAM50Call_RNAseq-SOX2
# PAM50Call_RNAseq-PCDHA12
# PAM50Call_RNAseq-FGG
# PAM50Call_RNAseq-IYD
# PAM50Call_RNAseq-CACNG4
# PAM50Call_RNAseq-DCDC2
# PAM50Call_RNAseq-EPYC
# PAM50Call_RNAseq-FAM83A
# PAM50Call_RNAseq-ADCY5
# PAM50Call_RNAseq-CHI3L2
# PAM50Call_RNAseq-PHGR1
# PAM50Call_RNAseq-TSIX
# PAM50Call_RNAseq-PCDH10
# PAM50Call_RNAseq-WT1
# PAM50Call_RNAseq-KCNG1
# PAM50Call_RNAseq-PP14571
# PAM50Call_RNAseq-SHISA2
# PAM50Call_RNAseq-HPX
# PAM50Call_RNAseq-EDN3
# PAM50Call_RNAseq-COL11A1
# PAM50Call_RNAseq-RIMS2
# PAM50Call_RNAseq-CD177
# PAM50Call_RNAseq-PCK1
# PAM50Call_RNAseq-TLX1
# PAM50Call_RNAseq-GLYATL1
# PAM50Call_RNAseq-MMP7
# PAM50Call_RNAseq-CYP4F11
# PAM50Call_RNAseq-TTC36
# PAM50Call_RNAseq-SEZ6L
# PAM50Call_RNAseq-S100A1
# PAM50Call_RNAseq-CHGA
# PAM50Call_RNAseq-LOC642587
# PAM50Call_RNAseq-PART1
# PAM50Call_RNAseq-NEURL
# PAM50Call_RNAseq-TBC1D3G
# PAM50Call_RNAseq-CNTFR
# PAM50Call_RNAseq-GABBR2
# PAM50Call_RNAseq-CRYM
# PAM50Call_RNAseq-RET
# PAM50Call_RNAseq-PPP1R1A
# PAM50Call_RNAseq-SLC15A1
# PAM50Call_RNAseq-PLA2G2D
# PAM50Call_RNAseq-SCRG1
# PAM50Call_RNAseq-LGR6
# PAM50Call_RNAseq-TOX3
# PAM50Call_RNAseq-HOXC10
# PAM50Call_RNAseq-ZFP57
# PAM50Call_RNAseq-SMOC1
# PAM50Call_RNAseq-TUBA3E
# PAM50Call_RNAseq-SLC6A11
# PAM50Call_RNAseq-RHCG
# PAM50Call_RNAseq-UGT2B28
# PAM50Call_RNAseq-HRASLS5
# PAM50Call_RNAseq-CXCL14
# PAM50Call_RNAseq-MKRN3
# PAM50Call_RNAseq-KCNF1
# PAM50Call_RNAseq-MKX
# PAM50Call_RNAseq-TSPAN1
# PAM50Call_RNAseq-CHRDL1
# PAM50Call_RNAseq-BCL11A
# PAM50Call_RNAseq-PLA2G3
# PAM50Call_RNAseq-MS4A8B
# PAM50Call_RNAseq-SLC6A15
# PAM50Call_RNAseq-FBN3
# PAM50Call_RNAseq-NKX2-2
# PAM50Call_RNAseq-FUT6
# PAM50Call_RNAseq-MAGEA1
# PAM50Call_RNAseq-MAPT
# PAM50Call_RNAseq-CTNND2
# PAM50Call_RNAseq-UGT8
# PAM50Call_RNAseq-DOK7
# PAM50Call_RNAseq-CPLX2
# PAM50Call_RNAseq-HP
# PAM50Call_RNAseq-FGFBP1
# PAM50Call_RNAseq-AKR1C2
# PAM50Call_RNAseq-OGN
# PAM50Call_RNAseq-CECR2
# PAM50Call_RNAseq-RASAL1
# PAM50Call_RNAseq-APOD
# PAM50Call_RNAseq-DEFB1
# PAM50Call_RNAseq-DACH1
# PAM50Call_RNAseq-ABCC12
# PAM50Call_RNAseq-TMEM40
# PAM50Call_RNAseq-PCSK1
# PAM50Call_RNAseq-LOC389033
# PAM50Call_RNAseq-ABCA8
# PAM50Call_RNAseq-SCARA5
# PAM50Call_RNAseq-SCNN1G
# PAM50Call_RNAseq-LY6K
# PAM50Call_RNAseq-FAT2
# PAM50Call_RNAseq-CPA6
# PAM50Call_RNAseq-MMP10
# PAM50Call_RNAseq-CLGN
# PAM50Call_RNAseq-C2orf40
# PAM50Call_RNAseq-NOVA1
# PAM50Call_RNAseq-CCL18
# PAM50Call_RNAseq-FGF10
# PAM50Call_RNAseq-SCGN
# PAM50Call_RNAseq-PIK3C2G
# PAM50Call_RNAseq-RBP4
# PAM50Call_RNAseq-CD79A
# PAM50Call_RNAseq-GRM4
# PAM50Call_RNAseq-ADAMTS15
# PAM50Call_RNAseq-TPSD1
# PAM50Call_RNAseq-C1orf106
# PAM50Call_RNAseq-?|652919
# PAM50Call_RNAseq-TNFSF12-TNFSF13
# PAM50Call_RNAseq-AQP7
# PAM50Call_RNAseq-PAH
# PAM50Call_RNAseq-FLT3
# PAM50Call_RNAseq-GPRIN2
# PAM50Call_RNAseq-GJB3
# PAM50Call_RNAseq-ADAMTS19
# PAM50Call_RNAseq-IRX4
# PAM50Call_RNAseq-CLSTN2
# PAM50Call_RNAseq-B3GNT3
# PAM50Call_RNAseq-PLIN5
# PAM50Call_RNAseq-FCRL5
# PAM50Call_RNAseq-NMU
# PAM50Call_RNAseq-SHC4
# PAM50Call_RNAseq-GATA4
# PAM50Call_RNAseq-PSAT1
# PAM50Call_RNAseq-SLC1A1
# PAM50Call_RNAseq-TMEM132C
# PAM50Call_RNAseq-DLGAP1
# PAM50Call_RNAseq-EMX1
# PAM50Call_RNAseq-PCOLCE2
# PAM50Call_RNAseq-ADAM6
# PAM50Call_RNAseq-MAOB
# PAM50Call_RNAseq-COL9A3
# PAM50Call_RNAseq-IRX1
# PAM50Call_RNAseq-AFP
# PAM50Call_RNAseq-LOC339535
# PAM50Call_RNAseq-PDZK1IP1
# PAM50Call_RNAseq-LOC84740
# PAM50Call_RNAseq-LOC440905
# PAM50Call_RNAseq-CDH1
# PAM50Call_RNAseq-ERBB2

# %%
directed_graph = nx.DiGraph();
print(directed_graph.number_of_edges())
if
# Out:
# 0
