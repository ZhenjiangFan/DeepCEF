# %%
import numpy as np
import pandas as pd
import networkx as nx

from sklearn.impute import SimpleImputer

# import Utils as Utils

# %%
data_path = "SmokerStatusPredictionBio-Signals/";
file_name = "train_dataset.csv";
dataset = pd.read_csv(data_path+file_name);
# display(train_dataset);

# file_name = "test_dataset.csv";
# test_dataset = pd.read_csv(data_path+file_name);
# display(test_dataset);

# frames = [train_dataset, test_dataset];
# dataset = pd.concat(frames, axis=0);

display(dataset);
#print(mixed_sim_dataset.columns);

# # dataset.replace({"NO": 0, "YES": 1}, inplace=True);
# print(dataset["Gravidity"].unique());
# dataset.replace({'1st':1, '2nd':2, '5th':5, '3rd':3, '4th':4, '6th':6, '7th':7}, inplace=True);
# print(dataset["Gender"].unique());
# dataset.replace({"Girl": 1, "girl": 1,"boy":2}, inplace=True);
# print(dataset["Baby-Weight(g)"].unique());
# dataset.replace({"A": 1, "B": 2,"C":3}, inplace=True);

# display(dataset);
# Out:
#        age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0       35         170          85       97.0             0.9
# 1       20         175         110      110.0             0.7
# 2       45         155          65       86.0             0.9
# 3       45         165          80       94.0             0.8
# 4       20         165          60       81.0             1.5
# ...    ...         ...         ...        ...             ...
# 38979   40         165          60       80.0             0.4
# 38980   45         155          55       75.0             1.5
# 38981   40         170         105      124.0             0.6
# 38982   40         160          55       75.0             1.5
# 38983   55         175          60       81.1             1.0
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 0                  0.9              1               1       118          78
# 1                  0.9              1               1       119          79
# 2                  0.9              1               1       110          80
# 3                  0.7              1               1       158          88
# 4                  0.1              1               1       109          64
# ...                ...            ...             ...       ...         ...
# 38979              0.6              1               1       107          60
# 38980              1.2              1               1       126          72
# 38981              0.5              1               1       141          85
# 38982              1.5              1               1        95          69
# 38983              1.0              1               1       114          66
#
#        ...  HDL  LDL  hemoglobin  Urine protein  serum creatinine   AST   ALT  \
# 0      ...   70  142        19.8              1               1.0    61   115
# 1      ...   71  114        15.9              1               1.1    19    25
# 2      ...   57  112        13.7              3               0.6  1090  1400
# 3      ...   46   91        16.9              1               0.9    32    36
# 4      ...   47   92        14.9              1               1.2    26    28
# ...    ...  ...  ...         ...            ...               ...   ...   ...
# 38979  ...   61   72        12.3              1               0.5    18    18
# 38980  ...   76  131        12.5              2               0.6    23    11
# 38981  ...   48  138        17.1              1               0.8    24    23
# 38982  ...   79  116        12.0              1               0.6    24    20
# 38983  ...   64  137        13.9              1               1.0    18    12
#
#        Gtp  dental caries  smoking
# 0      125              1        1
# 1       30              1        0
# 2      276              0        0
# 3       36              0        0
# 4       15              0        0
# ...    ...            ...      ...
# 38979   21              1        0
# 38980   12              0        0
# 38981   35              1        1
# 38982   17              0        1
# 38983   16              0        1
#
# [38984 rows x 23 columns]

# %%
# Randomly sample 70% of your dataframe
dataset = dataset.sample(frac=0.2);
dataset
# Out:
#        age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 15063   25         180          80       86.0             1.5
# 37458   45         165          85      100.0             0.6
# 18840   60         145          60       83.0             0.5
# 985     40         165          75       93.2             1.2
# 2255    20         170          70       79.0             1.0
# ...    ...         ...         ...        ...             ...
# 15136   40         165          70       86.4             0.4
# 24585   70         150          45       67.0             1.5
# 16166   40         160          55       69.0             1.5
# 2795    60         155          50       81.0             0.8
# 17890   40         175          65       71.0             0.4
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 15063              1.5              1               1       100          60
# 37458              0.8              1               1       111          78
# 18840              0.6              1               1       141         101
# 985                1.0              1               1       118          84
# 2255               1.2              1               1       139          75
# ...                ...            ...             ...       ...         ...
# 15136              0.3              1               1       120          77
# 24585              1.2              1               1       139          89
# 16166              1.5              1               1        90          60
# 2795               0.7              1               1       118          61
# 17890              0.8              1               1       128          82
#
#        ...  HDL  LDL  hemoglobin  Urine protein  serum creatinine  AST  ALT  \
# 15063  ...   58   78        14.9              1               0.9   15   20
# 37458  ...   62  126        13.5              1               0.7   24   30
# 18840  ...   59  101        12.8              1               0.7   77   91
# 985    ...   68  247        15.2              1               0.9   51   79
# 2255   ...   85   92        14.8              2               1.1   19   17
# ...    ...  ...  ...         ...            ...               ...  ...  ...
# 15136  ...   66  125        17.6              1               0.9   24   23
# 24585  ...   51  118        12.8              1               0.6   40   36
# 16166  ...   46  128        14.7              1               1.0   34   10
# 2795   ...   71   76        11.4              1               0.7   27   38
# 17890  ...   62   92        17.1              1               0.9   14   14
#
#        Gtp  dental caries  smoking
# 15063   10              0        0
# 37458   21              0        0
# 18840   54              0        0
# 985    106              0        0
# 2255    25              1        0
# ...    ...            ...      ...
# 15136   13              0        0
# 24585   25              0        0
# 16166   12              0        0
# 2795    30              0        0
# 17890   13              0        0
#
# [7797 rows x 23 columns]

# %%
# # Calculate the threshold for 50% missing values
# threshold = len(dataset.columns) * 0.85;

# # Drop rows with 50% or more missing values
# dataset = dataset.dropna(thresh=threshold);

# display(dataset);
# dataset.isnull().values.any()

# %%
# dataset['SepsisLabel'].unique()

# %%
# from sklearn.impute import KNNImputer
# imputer = KNNImputer(n_neighbors=2);
# dataset.loc[:,:] = imputer.fit_transform(dataset.loc[:,:]);
# dataset

# from sklearn.impute import SimpleImputer

# imputer = SimpleImputer(strategy='mean');

# # Define the condition for imputation
# condition = dataset['SepsisLabel'] == 1;

# # # Apply imputation only to rows that meet the condition
# dataset.loc[condition, :] = imputer.fit_transform(dataset.loc[condition, :]);

# # Define the condition for imputation
# condition = dataset['SepsisLabel'] == 0;

# # # Apply imputation only to rows that meet the condition
# dataset.loc[condition, :] = imputer.fit_transform(dataset.loc[condition, :]);

# display(dataset);

# %%
file_name = "processed_data.csv";
dataset.to_csv(data_path+file_name,index=None)

# %%
# dataset.isnull().values.any()
# Remove rows with any NaN values
# dataset.dropna(inplace=True);
# dataset.columns
# dataset['TYPE']

# # Remove tab characters from all columns
# dataset = dataset.replace('\t', '', regex=True);

# dataset = dataset.replace('>', '', regex=True);

# dataset = dataset.replace('<', '', regex=True);

# display(dataset);
